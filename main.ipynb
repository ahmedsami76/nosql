# %% [markdown]
# # Data Models and Query Languages

# %% [markdown]
# ## Operational VS Analytical

# %% [markdown]
# ![](images/transactional_vs_analytical.png)

# %% [markdown]
# # Storage And Retrieval

# %% [markdown]
# ## File Formats

# %% [markdown]
# ### XML (eXtensible Markup Language)

# %% [markdown]
# [XML Tutorial](https://www.w3schools.com/xml/default.asp)

# %% [markdown]
# ```xml
# <note>
#   <to>Tove</to>
#   <from>Jani</from>
#   <heading>Reminder</heading>
#   <body>Don't forget me this weekend!</body>
# </note>
# ```

# %% [markdown]
# **XML Tree Structure**

# %% [markdown]
# ```xml
# <?xml version="1.0" encoding="UTF-8"?>
# <bookstore>
#   <book category="cooking">
#     <title lang="en">Everyday Italian</title>
#     <author>Giada De Laurentiis</author>
#     <year>2005</year>
#     <price>30.00</price>
#   </book>
#   <book category="children">
#     <title lang="en">Harry Potter</title>
#     <author>J K. Rowling</author>
#     <year>2005</year>
#     <price>29.99</price>
#   </book>
#   <book category="web">
#     <title lang="en">Learning XML</title>
#     <author>Erik T. Ray</author>
#     <year>2003</year>
#     <price>39.95</price>
#   </book>
# </bookstore>
# ```

# %% [markdown]
# ![XMl Tree](images/xmltree.gif)

# %% [markdown]
# **XML Syntax Rules**

# %% [markdown]
# ```xml
# <root>
#   <child>
#     <subchild>.....</subchild>
#   </child>
# </root>
# ```

# %% [markdown]
# **XML Prolog**

# %% [markdown]
# ```xml
# <?xml version="1.0" encoding="UTF-8"?>
# ```

# %% [markdown]
# **XML Element**

# %% [markdown]
# ```xml
# <!-- The below full line is called the element -->
# <price>29.99</price>
# <!--
#        An element can contain:
#         - text
#         - attributes
#         - other elements
#         - or a mix of the above
#     -->
# ```

# %% [markdown]
# ```xml
# <!-- An empty XML element -->
# <element></element>
# <element />
# ```

# %% [markdown]
# **XML Attribute**

# %% [markdown]
# ```xml
# <person gender="female">
# ```

# %% [markdown]
# **XML Schema**

# %% [markdown]
# ```xml
# <xs:element name="note">
#
# <xs:complexType>
#   <xs:sequence>
#     <xs:element name="to" type="xs:string"/>
#     <xs:element name="from" type="xs:string"/>
#     <xs:element name="heading" type="xs:string"/>
#     <xs:element name="body" type="xs:string"/>
#   </xs:sequence>
# </xs:complexType>
#
# </xs:element>
# ```

# %% [markdown]
# The Schema above is interpreted like this:
#
# * <xs:element name="note"> defines the element called "note"
# * <<xs:complexType>> the "note" element is a complex type
# * <<xs:sequence>> the complex type is a sequence of elements
# * <xs:element name="to" type="xs:string"> the element "to" is of type string (text)
# * <xs:element name="from" type="xs:string"> the element "from" is of type string
# * <xs:element name="heading" type="xs:string"> the element "heading" is of type string
# * <xs:element name="body" type="xs:string"> the element "body" is of type string

# %% [markdown]
# | UserID    | Name      |   Email           |
# | --------  | -------   | -----             |
# | 1         | Alice     |  alice@email.com  |
# | 2         | Bob       |   bob@email.com   |

# %% [markdown]
# | OrderID   | UserID    | Product               | Price     |
# | --------  | -------   | -----                 | -----     |
# | 101       | 1         | Laptop                | 1000.00   |
# | 102       | 1         | Wireless Mouse        | 50.00     |
# | 103       | 2         | Mechanical Keyboard   | 120.00    |

# %% [markdown]
# ```xml
# <?xml version="1.0" encoding="UTF-8"?>
# <Users>
#     <User>
#         <UserID>1</UserID>
#         <Name>Alice</Name>
#         <Email>alice@email.com</Email>
#         <Orders>
#             <Order>
#                 <OrderID>101</OrderID>
#                 <Product>Laptop</Product>
#                 <Price>1000.00</Price>
#             </Order>
#             <Order>
#                 <OrderID>102</OrderID>
#                 <Product>Wireless Mouse</Product>
#                 <Price>50.00</Price>
#             </Order>
#         </Orders>
#     </User>
#     <User>
#         <UserID>2</UserID>
#         <Name>Bob</Name>
#         <Email>bob@email.com</Email>
#         <Orders>
#             <Order>
#                 <OrderID>103</OrderID>
#                 <Product>Mechanical Keyboard</Product>
#                 <Price>120.00</Price>
#             </Order>
#         </Orders>
#     </User>
# </Users>
# ```

# %% [markdown]
# # Replication

# %% [markdown]
# # Sharding
